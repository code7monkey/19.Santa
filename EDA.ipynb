# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

df= pd.read_csv('/content/drive/MyDrive/산타/data/data.csv')
df.head()
# Out:
#   point_id   x   y  demand
# 0    DEPOT   0   0       0
# 1  TOWN_01  34  94       2
# 2  TOWN_02  40  89       4
# 3  TOWN_03  39  95       1
# 4  TOWN_04  47  94       4

# %%
df['demand'].sum()
# Out:
# 287

# %%
# 287/25 = 11.48
# 12개의 route가 나온다

df['demand'].value_counts().sort_index()
# Out:
# demand
# 0     1
# 1    16
# 2     7
# 3    10
# 4    11
# 5    10
# 6    14
# 7     7
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#    point_id    x    y  demand
# 0     DEPOT    0    0       0
# 1   TOWN_01   34   94       2
# 2   TOWN_02   40   89       4
# 3   TOWN_03   39   95       1
# 4   TOWN_04   47   94       4
# 5   TOWN_05   34  100       6
# 6   TOWN_06   72   60       1
# 7   TOWN_07   67   54       4
# 8   TOWN_08   81   73       2
# 9   TOWN_09   71   63       4
# 10  TOWN_10    5   14       7
# 11  TOWN_11   13   17       7
# 12  TOWN_12   15   26       6
# 13  TOWN_13   22   15       7
# 14  TOWN_14    9  100       5
# 15  TOWN_15   10   87       7
# 16  TOWN_16    1   93       5
# 17  TOWN_17   60   69       3
# 18  TOWN_18   48   65       5
# 19  TOWN_19   68   77       2
# 20  TOWN_20    8   99       3
# 21  TOWN_21    2  100       1
# 22  TOWN_22    1   91       3
# 23  TOWN_23   13  100       5
# 24  TOWN_24    1  100       7
# 25  TOWN_25   87   28       1
# 26  TOWN_26   77   15       4
# 27  TOWN_27   82   14       5
# 28  TOWN_28   85   21       4
# 29  TOWN_29   21   11       2
# ...

# %%
# prompt: x=0, y=0까지의 유클리디안 거리를 distance 컬럼으로 추가

import math

# Calculate Euclidean distance
def euclidean_distance(x, y):
  return math.sqrt(x**2 + y**2)

# Apply the function to create the 'distance' column
df['distance'] = df.apply(lambda row: euclidean_distance(row['x'], row['y']), axis=1)
df.sort_values(by='distance')
# Out:
#    point_id    x    y  demand    distance
# 0     DEPOT    0    0       0    0.000000
# 10  TOWN_10    5   14       7   14.866069
# 11  TOWN_11   13   17       7   21.400935
# 30  TOWN_30    8   21       5   22.472205
# 29  TOWN_29   21   11       2   23.706539
# 13  TOWN_13   22   15       7   26.627054
# 12  TOWN_12   15   26       6   30.016662
# 31  TOWN_31   20   24       6   31.240999
# 32  TOWN_32   25   22       1   33.301652
# 68  TOWN_68   20   29       6   35.227830
# 41  TOWN_41   26   25       6   36.069378
# 58  TOWN_58   36   11       1   37.643060
# 56  TOWN_56   33   23       3   40.224371
# 37  TOWN_37   23   33       4   40.224371
# 45  TOWN_45   42    4       3   42.190046
# 50  TOWN_50   38   25       4   45.486262
# 40  TOWN_40   45   14       1   47.127487
# 38  TOWN_38   41   28       1   49.648766
# 54  TOWN_54   16   51       4   53.450912
# 39  TOWN_39   47   29       6   55.226805
# 65  TOWN_65   52   27       6   58.591808
# ...

# %%
depot_data = df[df['point_id'] == 'DEPOT'].iloc[0]
towns_data = df[df['point_id'] != 'DEPOT'].reset_index(drop=True)

# OR-Tools에 사용할 데이터 준비
# 출발지 좌표를 맨 앞에 두고 이후 마을 좌표들을 나열
locations = [(depot_data['x'], depot_data['y'])] + list(zip(towns_data['x'], towns_data['y']))
demands = [0] + list(towns_data['demand'])  # 출발지(창고)는 수요량(demand)이 0

# %%
depot_data
# Out:
# point_id    DEPOT
# x               0
# y               0
# demand          0
# distance      0.0
# Name: 0, dtype: object
